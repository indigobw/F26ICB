# %%
print("Hello World")
# Out:
# Hello World

# %%
1 + 5
# Out:
# 6

# %%
4 * 5 #multiplication
# Out:
# 20

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10%3
# Out:
# 1

# %%
3**3
# Out:
# 27

# %%
3 + 5 * 2
# Out:
# 13

# %%
(3+5) * 2
# Out:
# 16

# %%
3 < 5
# Out:
# True

# %%
2 + 2 == 6
# Out:
# False

# %%
2 + 2 != 6
# Out:
# True

# %%
x = 5

# %%
x
# Out:
# 5

# %%
who
# Out:
# x

# %%
y = "a"

# %%
who
# Out:
# x	 y

# %%
x + 2
# Out:
# 7

# %%
y = 3

# %%
x + y
# Out:
# 8

# %%
type(x)
# Out:
# int

# %%
height = 1.81

# %%
type(height)
# Out:
# float

# %%
type(1.0)
# Out:
# float

# %%
abs(-2.3)
# Out:
# 2.3

# %%
pow(3, 6)
# Out:
# 729

# %%
3**6
# Out:
# 729

# %%
round(5.444232434234, 2)
# Out:
# 5.44

# %%
Open = True

# %%
type(Open)
# Out:
# bool

# %%
Open
# Out:
# True

# %%
Open + Open
# Out:
# 2

# %%
seq ="AGGCTCCA"

# %%
myname = "Indigo Brookes-Weiss"

# %%
myname
# Out:
# 'Indigo Brookes-Weiss'

# %%
print(seq)
# Out:
# AGGCTCCA

# %%
print("My name is", myname)
# Out:
# My name is Indigo Brookes-Weiss

# %%
print("My name is", myname, sep=",")
# Out:
# My name is,Indigo Brookes-Weiss

# %%
len(seq)
# Out:
# 8

# %%
seq.count("G")
# Out:
# 2

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
help(seq.count)
# Out:
# Help on built-in function count:
#
# count(sub[, start[, end]], /) method of builtins.str instance
#     Return the number of non-overlapping occurrences of substring sub in string S[start:end].
#
#     Optional arguments start and end are interpreted as in slice
#     notation.

# %%
seq.replace("T", "U")
# Out:
# 'AGGCUCCA'

# %%
rna_seq = seq.replace("T", "U")

# %%
rna_seq
# Out:
# 'AGGCUCCA'

# %%
seq.find("T")
# Out:
# 4

# %%
myname.split("i")
# Out:
# ['Ind', 'go Brookes-We', 'ss']

# %%
upstream = "AAATA"
downstream = "CTTC"
promoter = "TAGCCTA"

# %%
upstream+"-"+promoter+"-"+downstream
# Out:
# 'AAATA-TAGCCTA-CTTC'

# %%
mylist = ["ATTA", 25, 3.4, True]

# %%
mylist
# Out:
# ['ATTA', 25, 3.4, True]

# %%
mylist[0]
# Out:
# 'ATTA'

# %%
mylist[1:3]
# Out:
# [25, 3.4]

# %%
mylist[3] = False

# %%
mylist
# Out:
# ['ATTA', 25, 3.4, False]

# %%
del(mylist[3])

# %%
mylist
# Out:
# ['ATTA', 25, 3.4]

# %%
gene = list("ACGTCGCTA")

# %%
gene.count("G")
# Out:
# 2

# %%
gene.append("p")

# %%
gene
# Out:
# ['A', 'C', 'G', 'T', 'C', 'G', 'C', 'T', 'A', 'p']

# %%
gene.index("T")
# Out:
# 3

# %%
a = [4,2,3,5,4]

# %%
a.sort()

# %%
a
# Out:
# [2, 3, 4, 4, 5]

# %%
a.reverse()

# %%
a
# Out:
# [5, 4, 4, 3, 2]

# %%
a = (4,2,3,5,4)

# %%
type(a)
# Out:
# tuple

# %%
a[2]
# Out:
# 3

# %%
a[2] = 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 a[2] = 4
#
# TypeError: 'tuple' object does not support item assignment

# %%
a.count(4)
# Out:
# 2

# %%
a.index(2)
# Out:
# 1

# %%
dict = {"a":"test", "b":55, "c":[1,2,3]}

# %%
dict
# Out:
# {'a': 'test', 'b': 55, 'c': [1, 2, 3]}

# %%
type(dict)
# Out:
# dict

# %%
cases = {"Riner":10,
        "Christiansburg":25,
        "Blacksburg":34}

# %%
cases
# Out:
# {'Riner': 10, 'Christiansburg': 25, 'Blacksburg': 34}

# %%
cases["Blacksburg"]
# Out:
# 34

# %%
cases["Merrimac"] = 3

# %%
cases
# Out:
# {'Riner': 10, 'Christiansburg': 25, 'Blacksburg': 34, 'Merrimac': 3}

# %%
cases["Merrimac"] = 13

# %%
cases
# Out:
# {'Riner': 10, 'Christiansburg': 25, 'Blacksburg': 34, 'Merrimac': 13}

# %%
cases.get("Blacksburg", "Not Found")
# Out:
# 34

# %%
cases.get("Rocky Mount", "Not Found")
# Out:
# 'Not Found'

# %%
cases.keys()
# Out:
# dict_keys(['Riner', 'Christiansburg', 'Blacksburg', 'Merrimac'])

# %%
cases.values()
# Out:
# dict_values([10, 25, 34, 13])

# %%
cases2 = {"Rocky Mount":32, "Riner":9}

# %%
cases.update(cases2)

# %%
cases
# Out:
# {'Riner': 9,
#  'Christiansburg': 25,
#  'Blacksburg': 34,
#  'Merrimac': 13,
#  'Rocky Mount': 32}

# %%
a = [1, 1, 2, 3, 5, 8]

# %%
a[4:]
# Out:
# [5, 8]

# %%
a[4:5]
# Out:
# [5]

# %%
a[4:6]
# Out:
# [5, 8]

# %%
a.append(13)

# %%
a
# Out:
# [1, 1, 2, 3, 5, 8, 13]

# %%
a.reverse()

# %%
a
# Out:
# [13, 8, 5, 3, 2, 1, 1]

# %%
m = {"a": ".-", "b": "-...-", "c": '-.-.'}

# %%
m
# Out:
# {'a': '.-', 'b': '-...-', 'c': '-.-.'}

# %%
m = {"a": ".-", "b": "-...-", "c": '-.-.', "d": "-.."}

# %%
m
# Out:
# {'a': '.-', 'b': '-...-', 'c': '-.-.', 'd': '-..'}
