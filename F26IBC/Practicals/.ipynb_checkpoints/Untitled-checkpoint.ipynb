# %%
#!/usr/bin/env python3

# %%
x = "Indigo"

# %%
x = "My name: Indigo"

# %%
y = "My favorite color: Purple"

# %%
z = "My favorite activity: Rowing"

# %%
t = "My favorite animal: Any cat"

# %%
x
# Out:
# 'My name: Indigo'

# %%
print(x, y, z, t)
# Out:
# My name: Indigo My favorite color: Purple My favorite activity: Rowing My favorite animal: Any cat

# %%
print(x,
      y,
      z,
      y)
# Out:
# My name: Indigo My favorite color: Purple My favorite activity: Rowing My favorite color: Purple

# %%
Print("x", "y", "z", "t", sep=\n)
# Out:
#   Cell In[15], line 1
#     Print(x, y, z, t, sep=\n)
#                            ^
# SyntaxError: unexpected character after line continuation character
